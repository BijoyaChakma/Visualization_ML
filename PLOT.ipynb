# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# #Do select the columns without species

# %%
new_df = df.iloc[: -1] [["sepal_length","sepal_width","petal_length","petal_width"]]

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
new_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 144           6.7          3.3           5.7          2.5
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
#
# [149 rows x 4 columns]

# %%
df = df[["sepal_length","sepal_width","petal_length"]]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
#visualization

# %%
#line plot
x =[10,15,12,14]
y =[15,18,16,17]
plt.plot(x,y)

# %%
#jevabe point dekbo

# %%
#line plot
x =[10,15,12,14]
y =[15,18,16,17]
plt.plot(x,y, "ro")

# %%
#line plot
x =[10,15,12,14]
y =[15,18,16,17]
plt.plot(x,y, marker="*")

# %%
#line plot
x =[10,15,12,14]
y =[15,18,16,17]
plt.plot(x,y, marker="*", color="r")

# %%
#line plot
x =[10,15,12,14]
y =[15,18,16,17]

plt.figure(figsize=(4,3))
plt.plot(x,y, marker="*", color="r")
plt.xlabel("value of X")
plt.ylabel("value of Y")
plt.title("value of x and y")
# Out:
# Text(0.5, 1.0, 'value of x and y')

# %%
plt.figure(figsize=(4,3))
plt.plot(x,y, marker="*", color="r")
plt.xlabel("value of X")
plt.ylabel("value of Y")
plt.title("value of x and y")
# Out:
# Text(0.5, 1.0, 'value of x and y')

# %%
plt.figure(figsize=(4,3))
plt.plot(x,y,"^k", marker="*", color="r")
plt.xlabel("value of X")
plt.ylabel("value of Y")
# Out:
# /tmp/ipython-input-907732949.py:2: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "^k" (-> marker='^'). The keyword argument will take precedence.
#   plt.plot(x,y,"^k", marker="*", color="r")
# /tmp/ipython-input-907732949.py:2: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "^k" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x,y,"^k", marker="*", color="r")
# Text(0, 0.5, 'value of Y')

# %%
plt.figure(figsize=(4,3))
plt.plot(x,y,"^k--", marker="*", color="r")
plt.xlabel("value of X")
plt.ylabel("value of Y")
# Out:
# /tmp/ipython-input-2705004923.py:2: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "^k--" (-> marker='^'). The keyword argument will take precedence.
#   plt.plot(x,y,"^k--", marker="*", color="r")
# /tmp/ipython-input-2705004923.py:2: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "^k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x,y,"^k--", marker="*", color="r")
# Text(0, 0.5, 'value of Y')

# %%
plt.figure(figsize=(4,3))
sns.lineplot(x=x,y=y, color="r")
plt.xlabel("value of X")
plt.ylabel("value of Y")
plt.title("value of x and y")
# Out:
# Text(0.5, 1.0, 'value of x and y')

# %%
#Scatter plot
plt.scatter(y,x)

# %%
import numpy as np
# prepare data
x = np.linspace(0,10,100) #100 points between 0 and 10
y = np.sin(x)

# create the plot
plt.plot(x,y)

# Add labels and title
plt.xlabel("time(s)")
plt.ylabel("Amplitude")
plt.title("Sine Wave")

#Display the plot
plt.show()

# %%
#Scatter plot
import numpy as np

#prepare data
x = np.linspace(0,10,100)
y = np.sin(x)
plt.scatter(y, x,)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
import numpy as np

#prepare data
x = np.linspace(0,10,100) #100 points between 0 and 10
y = np.sin(x)
plt.figure(figsize=(4,3))

plt.scatter(y, x,color="r")
plt.xlabel("value of X")
plt.ylabel("value of Y")
plt.title("value of x and y")
# Out:
# Text(0.5, 1.0, 'value of x and y')

# %%
#bar plot
y = [10,15,12,18]
x =["apple","samsung","redmi","nothing"]
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
#bar plot
y = [10,15,12,18]
x =["apple","samsung","redmi","nothing"]
colo =["red","green","blue","black"]
plt.bar(x,y, color ="b")
# Out:
# <BarContainer object of 4 artists>

# %%
#bar plot
y = [10,15,12,18]
x =["apple","samsung","redmi","nothing"]
colo =["red","green","blue","black"]
plt.bar(x,y, color =colo)
# Out:
# <BarContainer object of 4 artists>

# %%
#bar plot
y = [10,15,12,18]
x =["apple","samsung","redmi","nothing"]
colo =["red","green","blue","black"]
plt.bar(x,y, color =colo, width= .3)
# Out:
# <BarContainer object of 4 artists>

# %%
#bar plot
y = [10,15,12,18]
plt.figure(figsize=(4,3))
x =["apple","samsung","redmi","nothing"]
colo =["red","green","blue","black"]
plt.bar(x,y, color =colo, width= .3)
# Out:
# <BarContainer object of 4 artists>

# %%
#bar plot
y = [10,15,12,18]
plt.figure(figsize=(4,3))
x =["apple","samsung","redmi","nothing"]
colo =["red","green","blue","black"]
plt.bar(x,y, color =colo, width= .3)
plt.xlabel("name of mobile brand")
# Out:
# Text(0.5, 0, 'name of mobile brand')

# %%
#bar plot
y = [10,15,12,18]
plt.figure(figsize=(4,3))
x =["apple","samsung","redmi","nothing"]
colo =["red","green","blue","black"]
plt.bar(x,y, color =colo, width= .3)
plt.xlabel("name of mobile brand")
plt.legend()
# Out:
# /tmp/ipython-input-2673560621.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#bar plot
y = [10,15,12,18]
plt.figure(figsize=(4,3))
x =["apple","samsung","redmi","nothing"]
colo =["red","green","blue","black"]
plt.bar(x,y, color =colo, width= .3)
plt.xlabel("name of mobile brand")
plt.grid()

# %%
#bar plot
y = [10,15,12,18]
plt.figure(figsize=(4,3))
x =["apple","samsung","redmi","nothing"]
colo =["red","green","blue","black"]
sns.barplot(x=x,y=y, width= .3)
plt.xlabel("name of mobile brand")
plt.grid()

# %%
#bar plot
y = [10,15,12,18]
plt.figure(figsize=(4,3))
x =["apple","samsung","redmi","nothing"]
sns.barplot(x=x,y=y, width= .3, palette="Set1")
plt.xlabel("name of mobile brand")
plt.grid()
# Out:
# /tmp/ipython-input-741978130.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x,y=y, width= .3, palette="Set1")

# %%
#bar plot
y = [10,15,12,18]
plt.figure(figsize=(4,3))
x =["apple","samsung","redmi","nothing"]
sns.barplot(x=x,y=y, width= .4, palette="Set1")
plt.xlabel("name of mobile brand")
plt.grid()
# Out:
# /tmp/ipython-input-1587349584.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x,y=y, width= .4, palette="Set1")

# %%
#bar plot
y = [10,15,12,18]
plt.figure(figsize=(4,3))
sns.barplot(x=x,y=y, width= .4, palette="Set1")
plt.xlabel("name of mobile brand")
plt.legend( ["apple","samsung","redmi","nothing"])
plt.grid()
# Out:
# /tmp/ipython-input-3643819127.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x,y=y, width= .4, palette="Set1")

# %%
#pie plot
plt.pie(y)
# Out:
# ([<matplotlib.patches.Wedge at 0x7eb00813ac00>,
# ...
#  [Text(0.9253788637715525, 0.5947049339671486, ''),
#   Text(-0.456956526593232, 1.000595189276787, ''),
#   Text(-1.0132359391040946, -0.4281973046480365, ''),
#   Text(0.5680377130584303, -0.9419836285962451, '')])

# %%
#pie plot
plt.pie(y, labels=x, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x7eb00815b0b0>,
# ...
#  [Text(-0.5947048641029865, 0.9253789086705233, 'apple'),
#   Text(-1.0005950058821127, -0.45695692817132666, 'samsung'),
#   Text(0.4281974697251186, -1.0132358693418855, 'redmi'),
#   Text(0.9419838069125973, 0.5680374173542188, 'nothing')])

# %%
#pie plot
plt.pie(y, labels=x, startangle=180)
# Out:
# ([<matplotlib.patches.Wedge at 0x7eb00828e780>,
# ...
#  [Text(-0.9253786699920394, -0.5947052354938238, 'apple'),
#   Text(0.4569570911889389, -1.000594931434366, 'samsung'),
#   Text(1.0132357995796493, 0.4281976348021893, 'redmi'),
#   Text(-0.5680375708228531, 0.9419837143675427, 'nothing')])

# %%
#pie plot
plt.pie(y, labels=x, startangle=180,explode=[0,0,.2,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x7eb007d84170>,
# ...
#  [Text(-0.9253786699920394, -0.5947052354938238, 'apple'),
#   Text(0.4569570911889389, -1.000594931434366, 'samsung'),
#   Text(1.1974604904123127, 0.5060517502207692, 'redmi'),
#   Text(-0.5680375708228531, 0.9419837143675427, 'nothing')])

# %%
#pie plot
plt.pie(y, labels=x, startangle=180,explode=[0,0,.2,0],shadow=True, autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7eb008371160>,
# ...
#  [Text(-0.9253786699920394, -0.5947052354938238, 'apple'),
#   Text(0.4569570911889389, -1.000594931434366, 'samsung'),
#   Text(1.1974604904123127, 0.5060517502207692, 'redmi'),
#   Text(-0.5680375708228531, 0.9419837143675427, 'nothing')],
#  [Text(-0.5047520018138396, -0.324384673905722, '18.2%'),
#   Text(0.24924932246669393, -0.5457790535096542, '27.3%'),
#   Text(0.7368987633306538, 0.31141646167431947, '21.8%'),
#   Text(-0.30983867499428347, 0.5138092987459323, '32.7%')])

# %%
#sea born diye pie plot draw

# %%
#histogram
y =[10,15,12,18,13,20,40,25,26,24,21,23,26]
sns.histplot(y)
# Out:
# <Axes: ylabel='Count'>

# %%
#histogram
y =[10,15,12,18,13,20,40,25,26,24,21,23,26]
x = ["apple","samsung","apple","samsung","apple","samsung","apple","samsung","apple","samsung","apple","samsung","apple"]
sns.histplot(y, bins= 20)
# Out:
# <Axes: ylabel='Count'>

# %%
#histogram
y =[10,15,10,15,13,10,15,13,15,13,1,18]
x = ["apple","samsung","apple","samsung","apple","samsung","apple","samsung","apple","samsung","apple","samsung","apple"]
sns.histplot(y, bins= 20)
# Out:
# <Axes: ylabel='Count'>

# %%
#histogram
y =[10,15,10,15,13,13,10,15,13,15,13,1,18]
x = ["apple","samsung","apple","samsung","apple","samsung","apple","samsung","apple","samsung","apple","samsung","apple"]
sns.histplot(y)
# Out:
# <Axes: ylabel='Count'>

# %%
#histogram
y =[10,15,10,15,13,13,10,15,13,15,13,1,18]
x = ["apple","samsung","apple","samsung","apple","samsung","apple","samsung","apple","samsung","apple","samsung","apple"]
sns.histplot(y, bins=40, kde= True)
# Out:
# <Axes: ylabel='Count'>

# %%
#histogram
y =[10,15,10,15,13,13,10,15,13,15,13,1,18]
x = ["apple","samsung","apple","samsung","apple","samsung","apple","samsung","apple","samsung","apple","samsung","apple"]
sns.histplot(y, bins=40, kde= True, color="r", binwidth= 1.5)
# Out:
# <Axes: ylabel='Count'>

# %%
#histogram
y =[10,15,10,15,13,13,10,15,13,15,13,1,18]
sns.distplot(y, bins=40, kde= True, color="r")
# Out:
# /tmp/ipython-input-3873498718.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y, bins=40, kde= True, color="r")
# <Axes: ylabel='Density'>

# %%
#box plot
y = [10,15,10,15,13,13,10,15,13,15,13,1,18]
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7eb0057105f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7eb005710b90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7eb0057102f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7eb005711160>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7eb005711340>],
#  'means': []}

# %%
#box plot
y = [10,15,10,15,13,13,10,15,13,15,13,1,30]
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7eb005758140>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7eb005758710>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7eb00573fda0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7eb005758ce0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7eb005758f80>],
#  'means': []}

# %%
#box plot
y =[10,15,10,15,13,13,10,15,13,15,13,1,18]
sns.boxplot(y)
# Out:
# <Axes: >

# %%
#box plot
y =[10,15,10,15,13,13,10,15,13,15,13,1,18]
sns.boxplot(y, palette= "Set3",linecolor="r")
# Out:
# /tmp/ipython-input-4172673260.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y, palette= "Set3",linecolor="r")
# <Axes: >

# %%
#box plot
y =[10,15,10,15,13,13,10,15,13,15,13,1,18]
sns.violinplot(y, palette= "Set3",linecolor="r", linewidth=2)
# Out:
# /tmp/ipython-input-2784020072.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y, palette= "Set3",linecolor="r", linewidth=2)
# <Axes: >

# %%
sns.kdeplot(y)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(y, color ="r", fill=True)
# Out:
# <Axes: ylabel='Density'>

# %%
# 3d plot
import plotly.express as px
x =[10,15,12,14,19]
y =[10,120,151,123,152]
z =[1,2,3,4,6]
t =["joss","juice","joss","juice","joss"]
fig= px.scatter_3d(x=x,y=y,z=z, color=t)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
